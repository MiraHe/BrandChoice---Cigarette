# %%
import numpy as np
import pandas as pd
from datetime import datetime

## 讀入資料
from google.colab import drive
drive.mount("/content/gdrive")
df1 = pd.read_csv('/content/gdrive/MyDrive/專案code/Cigarette_Brand/188Category.csv',encoding="cp950")

## 新增欄位
df1['生活雜務']=df1['娛樂用品']=df1['嬰兒用品']=df1['個人用品']=df1['咖啡因']=df1['寵物用品']=df1['家俱']=df1['生鮮']=df1['美妝用品']=df1['熟食']=df1['甜點零食']=df1['罐頭調味']=df1['保健食品']=df1['酒精飲料']=df1['無酒精飲料']=df1['清潔用品']=df1['洗澡用品']=df1['醫療用品']=df1['交通費']=df1['手續費']=df1['香菸']=0


## 判斷包含字串與否
for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Tobacco/Smoking Accessories"
  B2="Garden/Flora"
  B3="Photo / Optical"
  B4="Wrap/Aluminum Foil"
  B5="Stationery/Printed Material"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A)):
    df1.生活雜務[index]=1
  else:
    df1.生活雜務[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Leisure entertainment vochur/curriculum"
  B2="Toys"
  B3="Sport/Outdoor supplies"
  B4="Newspaper/Magazine/Musical Instrument"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A)):
    df1.娛樂用品[index]=1
  else:
    df1.娛樂用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Baby Care"
  B2="Baby Food"
  B3="Milk Powder"
  B4="Infant Formula"
  B5="Mother&Baby Related Product"
  B6="Diaper"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A)):
    df1.嬰兒用品[index]=1
  else:
    df1.嬰兒用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Clothing/Personal Accessories"
  B2="Contact Lens"
  B3="Razor/Blade"

  if ((B1 in A) or (B2 in A) or (B3 in A)):
    df1.個人用品[index]=1
  else:
    df1.個人用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Coffee Capsule"
  B2="Instant Coffee"
  B3="Ready-To-Drink Coffee"
  B4="Roast & Ground Coffee"
  B5="OOH take away coffee"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A)):
    df1.咖啡因[index]=1
  else:
    df1.咖啡因[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Pet Food "
  B2="Pet Food / Pet Care "

  if ((B1 in A) or (B2 in A)):
    df1.寵物用品[index]=1
  else:
    df1.寵物用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Battery"
  B2="Computing/Telecommunications"
  B3="Counter"
  B4="Dehumidifier"
  B5="Disposable Warmers"
  B6="Home Decor"
  B7="Home Do It Yourself"
  B8="Home Furnishings/Decorations"
  B9="Homecare Merchandise"
  B10="Homecare Merchandise- Lighting"
  B11="Kitchen/Tableware/Cooking Ware"
  B12="Lamp"
  B13="Recharge Battery"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A)):
    df1.家俱[index]=1
  else:
    df1.家俱[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Egg"
  B2="Food - Perishable Fresh"
  B3="Fresh Fish"
  B4="Fresh Meat"
  B5="Frozen Dumpling"
  B6="Frozen Food"
  B7="Frozen Vegetable"
  B8="Fruit"
  B9="Cereal"
  B10="Cheese"
  B11="Jerky / Bean Curd"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A)):
    df1.生鮮[index]=1
  else:
    df1.生鮮[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Cosmetic II"
  B2="Cosmetic/Fragrances/Essential Oil"
  B3="Female Sanitary Protection"
  B4="General Skin Care"
  B5="Lip Balm"
  B6="Personal Care/Grooming/Hygiene"
  B7="Styling Aids"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A)):
    df1.美妝用品[index]=1
  else:
    df1.美妝用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Cooked Food"
  B2="Hot Pot"
  B3="Instant Food Pack"
  B4="Package Meat"
  B5="Package Rice"
  B6="Pie"
  B7="Rice & Bean Vermicelli"
  B8="Soup"
  B9="Noodle Stick/String"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A)):
    df1.熟食[index]=1
  else:
    df1.熟食[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Biscuit- II"
  B2="Bread"
  B3="Candy"
  B4="Chewing Gum"
  B5="Chocolate"
  B6="Confection/SweetBiscuit/Snacks"
  B7="Dessert"
  B8="Fruit Cake"
  B9="Dry Grain/Dry Food"
  B10="Dry Pasta"
  B11="Instant MIx Cereal"
  B12="Instant Noodle"
  B13="Jelly"
  B14="Preserved Fruit"
  B15="Pudding"
  B16="Rice Based Snack Food"
  B17="Ready-To-Eat Cereal"
  B18="Ice"
  B19="Nuts"
  B20="Oats"
  B21="Seaweed"
  B22="Snack"
  B23="Stick Biscuits"
  B24="Food - Frozen Grocery"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A) or (B15 in A) or (B16 in A) or (B17 in A) or (B18 in A) or (B19 in A) or (B20 in A) or (B21 in A) or (B22 in A) or (B23 in A) or (B24 in A)):
    df1.甜點零食[index]=1
  else:
    df1.甜點零食[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Concentrate Vinegar"
  B2="Butter"
  B3="Edible Oil"
  B4="Sauce"
  B5="Seasoning"
  B6="Soy Sauce"
  B7="Canned Food"
  B8="Canned Fruit"
  B9="Ready-To-Eat Canned Dessert"
  B10="Hot Pot Base"
  B11="Jam"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A)):
    df1.罐頭調味[index]=1
  else:
    df1.罐頭調味[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Glucosamine"
  B2="Vitamin"
  B3="Chicken Essence & Bird Nest"
  B4="Health Food"
  B5="Dietfood"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A)):
    df1.保健食品[index]=1
  else:
    df1.保健食品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Beer"
  B2="Beverages - Alcoholic"
  B3="Brandy"
  B4="Chinese Medical Wine"
  B5="Chinese White Wine"
  B6="Liqueur"
  B7="Local Brandy"
  B8="Low Alcoholic Drinks"
  B9="Others Ready-To-Drink"
  B10="Plum Liquor"
  B11="Sake"
  B12="Vodka"
  B13="Whisky"
  B14="Wine"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A)):
    df1.酒精飲料[index]=1
  else:
    df1.酒精飲料[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Beverages - Non Alcoholic"
  B2="Chilled Milk"
  B3="Chocolate Drinks"
  B4="Fermented Milk"
  B5="Functional Drink"
  B6="Ready-To-Drink Chinese Tea"
  B7="Ready-To-Drink Grain Drink"
  B8="Ready-To-Drink Tea"
  B9="Ready-To-Drink Vinegar"
  B10="Rice/Soybean Milk"
  B11="Shelf-Take Milk"
  B12="Sport Drink"
  B13="Tea Leaves"
  B14="Yogurt"
  B15="Juice Total"
  B16="Carbonated Soft Drink"
  B17="Bottled Water"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A) or (B15 in A) or (B16 in A) or (B17 in A)):
    df1.無酒精飲料[index]=1
  else:
    df1.無酒精飲料[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Disinfectant"
  B2="Contact Lense Cleanser"
  B3="Air Freshener"
  B4="Deodorant"
  B5="Fabric Detergent"
  B6="Household Cleanser"
  B7="Houseware/Cleaning Supplies"
  B8="Liquid Dish Wash"
  B9="Liquid Fabric Softener"
  B10="Paper Mop"
  B11="S.Bleach"
  B12="Scouring Pad"
  B13="Wet Tissue"
  B14="Insect Controller"
  B15="Kitchen Towel"
  B16="Food Storage Bag"
  B17="Facial Tissue"
  B18="Toilet Paper"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A) or (B15 in A) or (B16 in A) or (B17 in A) or (B18 in A)):
    df1.清潔用品[index]=1
  else:
    df1.清潔用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Face Care & Facial Cleansing"
  B2="Facial Foam"
  B3="Liquid Soap"
  B4="Mouth Wash"
  B5="Shampoo"
  B6="Shaving Cream"
  B7="Shower Gel"
  B8="Soap"
  B9="Toothbrush"
  B10="Toothpaste"
  B11="Hair Colouring"
  B12="Hair Conditioner"
  B13="Hot Spring Powder"
  B14="Dental Floss"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A)):
    df1.洗澡用品[index]=1
  else:
    df1.洗澡用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Adult Diaper"
  B2="Analgesics"
  B3="Anti-Fungal Medication"
  B4="Anti-Scar"
  B5="Chinese Medicine"
  B6="Cotton Swab"
  B7="Cold Medication"
  B8="Condom"
  B9="General Skin Medication"
  B10="Healthcare"
  B11="Medicine For Gastrointestinal"
  B12="Muscle  & Joint Topical Analge"
  B13="Pregnancy Test"
  B14="Rhinitis"
  B15="Sanitary Protection"
  B16="Eyedrops"

  if ((B1 in A) or (B2 in A) or (B3 in A) or (B4 in A) or (B5 in A) or (B6 in A) or (B7 in A) or (B8 in A) or (B9 in A) or (B10 in A) or (B11 in A) or (B12 in A) or (B13 in A) or (B14 in A) or (B15 in A) or (B16 in A)):
    df1.醫療用品[index]=1
  else:
    df1.醫療用品[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Automotive_Motor"

  if ((B1 in A)):
    df1.交通費[index]=1
  else:
    df1.交通費[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Others"

  if ((B1 in A)):
    df1.手續費[index]=1
  else:
    df1.手續費[index]=0


for index in range(len(df1)-1):
  A=bytes.decode(df1.category[index].encode("utf8"))
  B1="Cigarette"

  if ((B1 in A)):
    df1.香菸[index]=1
  else:
    df1.香菸[index]=0


## 無小計輸出到 csv 檔案
df1.to_csv('/content/gdrive/MyDrive/專案code/Cigarette_Brand/Category21_not_count.csv', encoding="cp950", index=False)

## groupby 日期
## df2= df1.groupby(['xdid', 'invDate']).sum()
df2= df1.groupby(['xdid']).sum()


## 小計輸出到 csv 檔案
df2.reset_index().to_csv ('/content/gdrive/MyDrive/專案code/Cigarette_Brand/Category21_count.csv', encoding="cp950", index=False)
# Out:
# Mounted at /content/gdrive
# <ipython-input-2-059ae01b4aca>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.生活雜務[index]=0
# <ipython-input-2-059ae01b4aca>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.生活雜務[index]=1
# <ipython-input-2-059ae01b4aca>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.娛樂用品[index]=0
# <ipython-input-2-059ae01b4aca>:37: SettingWithCopyWarning:
# ...
